# %%
import fiona

# %%
shape = fiona.open("1_DADOS_LOCALIZACAO_GEOESTE/LIMITE_MUNICIPIOS_OESTE/Muni_mesoeste.shp")

# %%
print(shape.schema)
# Out:
# {'properties': OrderedDict([('OBJECTID', 'int:9'), ('ID_OBJETO', 'float:19.11'), ('NOME', 'str:100'), ('NOMEABREV', 'str:50'), ('GEOMETRIAA', 'str:3'), ('GEOCODIGO', 'str:15'), ('ANODEREFER', 'float:19.11'), ('SHAPE_Leng', 'float:19.11'), ('SHAPE_Area', 'float:19.11'), ('Contagem', 'int:10'), ('Responsave', 'str:250')]), 'geometry': '3D Polygon'}

# %%
first = shape.next()
# Out:
# <ipython-input-26-53fd301b3e34>:1: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   first = shape.next()

# %%
print(first)
# Out:
# {'type': 'Feature', 'id': '2', 'properties': OrderedDict([('OBJECTID', 388), ('ID_OBJETO', 44769.0), ('NOME', 'Marechal Cândido Rondon'), ('NOMEABREV', None), ('GEOMETRIAA', 'Não'), ('GEOCODIGO', '4114609'), ('ANODEREFER', 0.0), ('SHAPE_Leng', 1.93026632449), ('SHAPE_Area', 0.06666491312), ('Contagem', 3), ('Responsave', 'Fábio')]), 'geometry': {'type': 'Polygon', 'coordinates': [[(-54.09552958899991, -24.46829831799994, 0.0), (-54.096438418999924, -24.46748701599995, 0.0), (-54.09693544399994, -24.466053936999913, 0.0), (-54.09599450199994, -24.460919343999933, 0.0), (-54.097176272999945, -24.45982889499993, 0.0), (-54.09930325799991, -24.45918109899992, 0.0), (-54.100113423999915, -24.45844025899993, 0.0), (-54.10094824499993, -24.45647066999993, 0.0), (-54.100536001999956, -24.45526298099992, 0.0), (-54.09955582099991, -24.45424435399991, 0.0), (-54.099054277999926, -24.45106407299994, 0.0), (-54.09476958099992, -24.45050436699995, 0.0), (-54.093912976999945, -24.45110527199995, 0
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = gpd.read_file("1_DADOS_LOCALIZACAO_GEOESTE/LIMITE_MUNICIPIOS_OESTE/Muni_mesoeste.shp")

# %%
ax = df.plot(color='blue')
